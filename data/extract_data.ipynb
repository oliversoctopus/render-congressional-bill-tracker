# %%
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime, timedelta
from tqdm import tqdm
import os
import json
import pickle
from dotenv import load_dotenv
import logging
from typing import Dict, List, Optional, Tuple

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('../data/extraction_log.log'),
        logging.StreamHandler()
    ]
)

# Load environment variables
load_dotenv()
CONGRESS_API_KEY = os.getenv('CONGRESS_API_KEY')

# Configuration
CACHE_DIR = '../data/api_cache'
CHECKPOINT_FILE = '../data/extraction_checkpoint.pkl'
MAX_RETRIES = 3
RETRY_DELAY = 5  # seconds
RATE_LIMIT_DELAY = 0.75  # seconds between API calls

# Create cache directory if it doesn't exist
os.makedirs(CACHE_DIR, exist_ok=True)

def save_checkpoint(state: Dict):
    """Save current extraction state for resumption"""
    with open(CHECKPOINT_FILE, 'wb') as f:
        pickle.dump(state, f)
    logging.info(f"Checkpoint saved: {state['bills_processed']} bills processed")

def load_checkpoint() -> Optional[Dict]:
    """Load previous extraction state if exists"""
    if os.path.exists(CHECKPOINT_FILE):
        with open(CHECKPOINT_FILE, 'rb') as f:
            state = pickle.load(f)
        logging.info(f"Checkpoint loaded: {state['bills_processed']} bills already processed")
        return state
    return None

def fetch_with_retry(url: str, max_retries: int = MAX_RETRIES) -> Optional[Dict]:
    """Fetch URL with retry logic and caching"""
    # Check cache first
    cache_key = url.replace('/', '_').replace(':', '').replace('?', '_')
    cache_file = os.path.join(CACHE_DIR, f"{cache_key}.json")
    
    if os.path.exists(cache_file):
        try:
            with open(cache_file, 'r') as f:
                return json.load(f)
        except:
            pass  # If cache is corrupted, fetch fresh
    
    # Fetch from API with retries
    for attempt in range(max_retries):
        try:
            response = requests.get(url, timeout=30)
            if response.status_code == 200:
                data = response.json()
                # Cache the response
                with open(cache_file, 'w') as f:
                    json.dump(data, f)
                return data
            elif response.status_code == 429:  # Rate limited
                wait_time = int(response.headers.get('Retry-After', 60))
                logging.warning(f"Rate limited. Waiting {wait_time} seconds...")
                time.sleep(wait_time)
            else:
                logging.warning(f"HTTP {response.status_code} for {url}")
                
        except requests.exceptions.Timeout:
            logging.warning(f"Timeout on attempt {attempt + 1} for {url}")
        except Exception as e:
            logging.error(f"Error on attempt {attempt + 1} for {url}: {str(e)}")
        
        if attempt < max_retries - 1:
            time.sleep(RETRY_DELAY * (attempt + 1))
    
    return None

def get_all_bills_for_congress(congress: int, bill_type: str = 'hr', limit: int = 250) -> List[Dict]:
    """Get all bills for a specific congress and type"""
    all_bills = []
    offset = 0
    
    logging.info(f"Fetching all {bill_type.upper()} bills from Congress {congress}")
    
    while True:
        url = f"https://api.congress.gov/v3/bill/{congress}/{bill_type}?api_key={CONGRESS_API_KEY}&limit={limit}&offset={offset}"
        
        data = fetch_with_retry(url)
        if not data:
            break
            
        bills = data.get('bills', [])
        if not bills:
            break
            
        all_bills.extend(bills)
        offset += limit
        
        # Check if we've reached the end
        pagination = data.get('pagination', {})
        if offset >= pagination.get('count', 0):
            break
            
        time.sleep(RATE_LIMIT_DELAY)
    
    logging.info(f"Found {len(all_bills)} {bill_type.upper()} bills in Congress {congress}")
    return all_bills

def fetch_detailed_bill_info(congress: int, bill_type: str, bill_number: str) -> Optional[Dict]:
    """Fetch comprehensive bill information"""
    base_url = f"https://api.congress.gov/v3/bill/{congress}/{bill_type}/{bill_number}"
    
    # Main bill info
    bill_data = fetch_with_retry(f"{base_url}?api_key={CONGRESS_API_KEY}")
    if not bill_data:
        return None
    
    # Get additional data
    result = {'bill': bill_data.get('bill', {})}
    
    # Cosponsors (with pagination)
    all_cosponsors = []
    offset = 0
    while True:
        cosponsor_url = f"{base_url}/cosponsors?api_key={CONGRESS_API_KEY}&limit=250&offset={offset}"
        cosponsor_data = fetch_with_retry(cosponsor_url)
        if cosponsor_data:
            cosponsors = cosponsor_data.get('cosponsors', [])
            if not cosponsors:
                break
            all_cosponsors.extend(cosponsors)
            if len(cosponsors) < 250:
                break
            offset += 250
            time.sleep(RATE_LIMIT_DELAY)
        else:
            break
    result['cosponsors'] = all_cosponsors
    
    # Subjects
    subjects_data = fetch_with_retry(f"{base_url}/subjects?api_key={CONGRESS_API_KEY}")
    result['subjects'] = subjects_data.get('subjects', {}) if subjects_data else {}
    
    # Actions (with pagination)
    all_actions = []
    offset = 0
    while True:
        actions_url = f"{base_url}/actions?api_key={CONGRESS_API_KEY}&limit=250&offset={offset}"
        actions_data = fetch_with_retry(actions_url)
        if actions_data:
            actions = actions_data.get('actions', [])
            if not actions:
                break
            all_actions.extend(actions)
            if len(actions) < 250:
                break
            offset += 250
            time.sleep(RATE_LIMIT_DELAY)
        else:
            break
    result['actions'] = all_actions
    
    # Committees
    committees_data = fetch_with_retry(f"{base_url}/committees?api_key={CONGRESS_API_KEY}")
    result['committees'] = committees_data.get('committees', {}) if committees_data else {}
    
    return result

def extract_features_safe(bill_info: Dict) -> Optional[Dict]:
    """Safely extract features with comprehensive error handling"""
    try:
        if not bill_info or not bill_info.get('bill'):
            return None
        
        bill = bill_info['bill']
        
        # Basic info
        features = {
            'bill_id': f"{bill.get('congress')}-{bill.get('type')}-{bill.get('number')}",
            'congress': bill.get('congress'),
            'bill_type': bill.get('type'),
            'bill_number': bill.get('number'),
            'title': bill.get('title', ''),
            'introduced_date': bill.get('introducedDate'),
            'url': bill.get('url', ''),
        }
        
        # Policy area
        policy_area = bill.get('policyArea')
        if isinstance(policy_area, dict):
            features['policy_area'] = policy_area.get('name', 'Unknown')
        else:
            features['policy_area'] = 'Unknown'
        
        # Sponsor information
        sponsors = bill.get('sponsors', [])
        if isinstance(sponsors, list) and sponsors:
            main_sponsor = sponsors[0]
            features['sponsor_name'] = main_sponsor.get('fullName', '')
            features['sponsor_party'] = main_sponsor.get('party', 'Unknown')
            features['sponsor_state'] = main_sponsor.get('state', '')
            features['sponsor_bioguide_id'] = main_sponsor.get('bioguideId', '')
        else:
            features['sponsor_name'] = ''
            features['sponsor_party'] = 'Unknown'
            features['sponsor_state'] = ''
            features['sponsor_bioguide_id'] = ''
        
        features['sponsor_count'] = len(sponsors) if isinstance(sponsors, list) else 0
        
        # Count sponsors by party
        if isinstance(sponsors, list):
            sponsor_parties = [s.get('party', 'Unknown') for s in sponsors if isinstance(s, dict)]
            features['dem_sponsors'] = sponsor_parties.count('D')
            features['rep_sponsors'] = sponsor_parties.count('R')
            features['ind_sponsors'] = features['sponsor_count'] - features['dem_sponsors'] - features['rep_sponsors']
        else:
            features['dem_sponsors'] = 0
            features['rep_sponsors'] = 0
            features['ind_sponsors'] = 0
        
        # Cosponsor information
        cosponsors = bill_info.get('cosponsors', [])
        if not isinstance(cosponsors, list):
            cosponsors = []
        features['cosponsor_count'] = len(cosponsors)
        
        # Count cosponsors by party
        cosponsor_parties = [c.get('party', 'Unknown') for c in cosponsors if isinstance(c, dict)]
        features['dem_cosponsors'] = cosponsor_parties.count('D')
        features['rep_cosponsors'] = cosponsor_parties.count('R')
        features['ind_cosponsors'] = features['cosponsor_count'] - features['dem_cosponsors'] - features['rep_cosponsors']
        
        # Original cosponsors
        original_cosponsors = [c for c in cosponsors if isinstance(c, dict) and c.get('isOriginalCosponsor', False)]
        features['original_cosponsor_count'] = len(original_cosponsors)
        
        # Bipartisan features
        total_sponsors = features['sponsor_count'] + features['cosponsor_count']
        total_dem = features['dem_sponsors'] + features['dem_cosponsors']
        total_rep = features['rep_sponsors'] + features['rep_cosponsors']
        
        features['is_bipartisan'] = int(total_dem > 0 and total_rep > 0)
        features['bipartisan_ratio'] = min(total_dem, total_rep) / total_sponsors * 2 if total_sponsors > 0 else 0
        
        # Committee information from bill data
        committees_in_bill = bill.get('committees', {})
        if isinstance(committees_in_bill, dict):
            committee_items = committees_in_bill.get('item', [])
            if isinstance(committee_items, dict):
                committee_items = [committee_items]
            elif not isinstance(committee_items, list):
                committee_items = []
        else:
            committee_items = []
        
        # Also check committees endpoint data
        committees_data = bill_info.get('committees', {})
        if isinstance(committees_data, dict):
            additional_items = committees_data.get('item', [])
            if isinstance(additional_items, list):
                committee_items.extend(additional_items)
        
        features['committee_count'] = len(set(c.get('name', '') for c in committee_items if isinstance(c, dict)))
        
        # Latest action
        latest_action = bill.get('latestAction', {})
        if isinstance(latest_action, dict):
            features['latest_action'] = latest_action.get('text', '')
            features['latest_action_date'] = latest_action.get('actionDate', '')
        else:
            features['latest_action'] = ''
            features['latest_action_date'] = ''
        
        # Actions analysis
        actions = bill_info.get('actions', [])
        if not isinstance(actions, list):
            actions = []
        features['action_count'] = len(actions)
        
        # Analyze action types
        action_texts = [a.get('text', '').lower() for a in actions if isinstance(a, dict)]
        features['referred_to_committee'] = sum(1 for a in action_texts if 'referred to' in a)
        features['reported_by_committee'] = sum(1 for a in action_texts if 'reported' in a)
        features['passed_house'] = int(any('passed house' in a or 'passed the house' in a for a in action_texts))
        features['passed_senate'] = int(any('passed senate' in a or 'passed the senate' in a for a in action_texts))
        features['has_amendments'] = int(any('amendment' in a for a in action_texts))
        features['has_vote'] = int(any('vote' in a or 'yea-and-nay' in a or 'roll no' in a for a in action_texts))
        
        # Subjects
        subjects_data = bill_info.get('subjects', {})
        subject_count = 0
        subject_names = []
        
        if isinstance(subjects_data, dict):
            # Try different structures
            for key in ['legislativeSubjects', 'policyArea']:
                subj_items = subjects_data.get(key, {})
                if isinstance(subj_items, dict) and 'item' in subj_items:
                    items = subj_items['item']
                    if isinstance(items, list):
                        subject_names.extend([s.get('name', '') for s in items if isinstance(s, dict)])
                elif isinstance(subj_items, list):
                    subject_names.extend([s.get('name', '') for s in subj_items if isinstance(s, dict)])
        
        features['subject_count'] = len(subject_names)
        features['subjects'] = '; '.join(subject_names[:10])  # First 10 subjects
        
        # Title analysis
        features['title_length'] = len(features['title'])
        features['title_word_count'] = len(features['title'].split())
        
        # Determine passage status
        latest = features['latest_action'].lower()
        if features['passed_house'] and features['passed_senate']:
            features['passed'] = 1
        elif any(term in latest for term in ['became public law', 'signed by president', 'enacted']):
            features['passed'] = 1
        elif any(term in latest for term in ['failed', 'rejected', 'vetoed', 'motion to proceed not agreed']):
            features['passed'] = 0
        elif features['action_count'] < 3 and 'introduced' in latest:
            features['passed'] = 0  # Bills with minimal action typically don't pass
        else:
            features['passed'] = -1  # Unknown/pending
        
        return features
        
    except Exception as e:
        logging.error(f"Error extracting features: {str(e)}")
        return None

def extract_comprehensive_dataset():
    """Extract comprehensive dataset with resume capability"""
    # Load checkpoint if exists
    checkpoint = load_checkpoint()
    if checkpoint:
        all_features = checkpoint['features']
        processed_bills = set(checkpoint['processed_bills'])
        start_congress = checkpoint['current_congress']
        start_type_idx = checkpoint['current_type_idx']
    else:
        all_features = []
        processed_bills = set()
        start_congress = 113  # Start from 113th Congress (2013-2014)
        start_type_idx = 0
    
    # Define what to extract
    congresses = list(range(start_congress, 119))  # 113th to 118th Congress
    bill_types = ['hr', 's', 'hjres', 'sjres']  # House bills, Senate bills, Joint resolutions
    
    total_bills_processed = len(processed_bills)
    
    for congress in congresses:
        for type_idx, bill_type in enumerate(bill_types):
            # Skip if already processed
            if congress < start_congress or (congress == start_congress and type_idx < start_type_idx):
                continue
            
            try:
                # Get all bills for this congress and type
                bills = get_all_bills_for_congress(congress, bill_type)
                
                # Process each bill
                for bill in tqdm(bills, desc=f"Congress {congress} {bill_type.upper()}"):
                    bill_number = bill.get('number', '')
                    bill_key = f"{congress}-{bill_type}-{bill_number}"
                    
                    # Skip if already processed
                    if bill_key in processed_bills:
                        continue
                    
                    # Fetch detailed info
                    detailed_info = fetch_detailed_bill_info(congress, bill_type, bill_number)
                    if detailed_info:
                        features = extract_features_safe(detailed_info)
                        if features:
                            all_features.append(features)
                            processed_bills.add(bill_key)
                            total_bills_processed += 1
                    
                    # Save checkpoint every 100 bills
                    if total_bills_processed % 100 == 0:
                        save_checkpoint({
                            'features': all_features,
                            'processed_bills': list(processed_bills),
                            'bills_processed': total_bills_processed,
                            'current_congress': congress,
                            'current_type_idx': type_idx
                        })
                    
                    # Rate limiting
                    time.sleep(RATE_LIMIT_DELAY)
                    
            except Exception as e:
                logging.error(f"Error processing {congress} {bill_type}: {str(e)}")
                # Save checkpoint on error
                save_checkpoint({
                    'features': all_features,
                    'processed_bills': list(processed_bills),
                    'bills_processed': total_bills_processed,
                    'current_congress': congress,
                    'current_type_idx': type_idx
                })
                continue
    
    # Create final dataset
    if all_features:
        df = pd.DataFrame(all_features)
        
        # Add calculated features
        if 'introduced_date' in df.columns:
            df['introduced_date'] = pd.to_datetime(df['introduced_date'], errors='coerce')
            df['days_since_introduction'] = (datetime.now() - df['introduced_date']).dt.days
            df['month_introduced'] = df['introduced_date'].dt.month
            df['quarter_introduced'] = df['introduced_date'].dt.quarter  
            df['year_introduced'] = df['introduced_date'].dt.year
            df['is_election_year'] = (df['year_introduced'] % 4 == 0).astype(int)
        
        # Activity metrics
        df['actions_per_day'] = df['action_count'] / (df.get('days_since_introduction', 1).fillna(1) + 1)
        df['has_multiple_actions'] = (df['action_count'] > 3).astype(int)
        
        # Save datasets
        df.to_csv('../data/bills_with_features_full.csv', index=False)
        logging.info(f"Saved {len(df)} bills to bills_with_features_full.csv")
        
        # Create training dataset
        training_df = df[df['passed'] != -1].copy()
        training_df.to_csv('../data/bills_training_data_full.csv', index=False)
        logging.info(f"Saved {len(training_df)} bills with known outcomes for training")
        
        # Print summary
        print("\n" + "="*60)
        print("EXTRACTION COMPLETE")
        print("="*60)
        print(f"Total bills extracted: {len(df)}")
        print(f"Bills with known outcomes: {len(training_df)}")
        print(f"Pass rate: {(training_df['passed'] == 1).mean()*100:.1f}%")
        print("\nBills by Congress:")
        print(df['congress'].value_counts().sort_index())
        print("\nBills by type:")
        print(df['bill_type'].value_counts())
        print("\nSponsor party distribution:")
        print(df['sponsor_party'].value_counts())
        
        # Clean up checkpoint
        if os.path.exists(CHECKPOINT_FILE):
            os.remove(CHECKPOINT_FILE)
            
        return df
    else:
        logging.error("No data extracted!")
        return pd.DataFrame()

if __name__ == "__main__":
    if not CONGRESS_API_KEY:
        print("ERROR: CONGRESS_API_KEY not found!")
        print("Please add your API key to the .env file")
    else:
        print("Starting comprehensive bill extraction...")
        print("This will fetch bills from the 113th-118th Congress")
        print("The process is resumable - you can stop and restart anytime")
        print("-" * 60)
        
        df = extract_comprehensive_dataset()
        
        if not df.empty:
            print("\nExtraction completed successfully!")
            print(f"Full dataset: ../data/bills_with_features_full.csv")
            print(f"Training dataset: ../data/bills_training_data_full.csv")
        else:
            print("\nExtraction failed - check the log file for details")
# Out:
# 2025-07-27 16:33:21,658 - INFO - Checkpoint loaded: 12100 bills already processed
# 2025-07-27 16:33:21,661 - INFO - Fetching all HR bills from Congress 114
# Starting comprehensive bill extraction...
# This will fetch bills from the 113th-118th Congress
# The process is resumable - you can stop and restart anytime
# ------------------------------------------------------------
# 2025-07-27 16:33:41,270 - INFO - Found 6536 HR bills in Congress 114
# Congress 114 HR:  46%|█████████████████████████████                                  | 3010/6536 [00:00<00:00, 3978.51it/s]2025-07-27 16:33:50,672 - WARNING - Rate limited. Waiting 1184 seconds...
# Congress 114 HR:  48%|█████████████████████████████▉                                 | 3108/6536 [25:44<3:35:19,  3.77s/it]2025-07-27 16:59:29,552 - INFO - Checkpoint saved: 12200 bills processed
# Congress 114 HR:  49%|██████████████████████████████▉                                | 3208/6536 [32:46<3:28:03,  3.75s/it]2025-07-27 17:06:30,697 - INFO - Checkpoint saved: 12300 bills processed
# Congress 114 HR:  51%|███████████████████████████████▉                               | 3308/6536 [39:04<3:24:22,  3.80s/it]2025-07-27 17:12:51,849 - INFO - Checkpoint saved: 12400 bills processed
# Congress 114 HR:  52%|████████████████████████████████▊                              | 3408/6536 [45:37<3:32:28,  4.08s/it]2025-07-27 17:19:21,522 - INFO - Checkpoint saved: 12500 bills processed
# Congress 114 HR:  54%|█████████████████████████████████▊                             | 3508/6536 [51:45<2:58:43,  3.54s/it]2025-07-27 17:25:29,521 - INFO - Checkpoint saved: 12600 bills processed
# Congress 114 HR:  55%|██████████████████████████████████▊                            | 3608/6536 [57:30<2:46:50,  3.42s/it]2025-07-27 17:31:14,479 - INFO - Checkpoint saved: 12700 bills processed
# Congress 114 HR:  57%|██████████████████████████████████▌                          | 3708/6536 [1:03:07<2:43:20,  3.47s/it]2025-07-27 17:36:51,087 - INFO - Checkpoint saved: 12800 bills processed
# Congress 114 HR:  58%|███████████████████████████████████▌                         | 3808/6536 [1:08:40<2:23:33,  3.16s/it]2025-07-27 17:42:24,776 - INFO - Checkpoint saved: 12900 bills processed
# Congress 114 HR:  60%|████████████████████████████████████▍                        | 3908/6536 [1:14:25<2:29:44,  3.42s/it]2025-07-27 17:48:10,776 - INFO - Checkpoint saved: 13000 bills processed
# Congress 114 HR:  61%|█████████████████████████████████████▍                       | 4008/6536 [1:20:07<2:15:14,  3.21s/it]2025-07-27 17:53:51,360 - INFO - Checkpoint saved: 13100 bills processed
# Congress 114 HR:  63%|██████████████████████████████████████▎                      | 4108/6536 [1:25:43<2:12:51,  3.28s/it]2025-07-27 17:59:27,023 - INFO - Checkpoint saved: 13200 bills processed
# Congress 114 HR:  63%|██████████████████████████████████████▍                      | 4114/6536 [1:26:03<2:14:17,  3.33s/it]2025-07-27 17:59:45,198 - WARNING - Rate limited. Waiting 3601 seconds...
# Congress 114 HR:  64%|███████████████████████████████████████▎                     | 4208/6536 [2:31:41<2:57:32,  4.58s/it]2025-07-27 19:05:25,444 - INFO - Checkpoint saved: 13300 bills processed
# Congress 114 HR:  66%|████████████████████████████████████████▏                    | 4308/6536 [2:37:40<2:15:34,  3.65s/it]2025-07-27 19:11:25,262 - INFO - Checkpoint saved: 13400 bills processed
# Congress 114 HR:  67%|█████████████████████████████████████████▏                   | 4408/6536 [2:43:27<1:53:33,  3.20s/it]2025-07-27 19:17:11,729 - INFO - Checkpoint saved: 13500 bills processed
# Congress 114 HR:  69%|██████████████████████████████████████████                   | 4508/6536 [2:49:27<2:03:08,  3.64s/it]2025-07-27 19:23:11,677 - INFO - Checkpoint saved: 13600 bills processed
# Congress 114 HR:  71%|███████████████████████████████████████████                  | 4608/6536 [2:55:04<1:50:13,  3.43s/it]2025-07-27 19:28:48,175 - INFO - Checkpoint saved: 13700 bills processed
# Congress 114 HR:  72%|███████████████████████████████████████████▉                 | 4708/6536 [3:01:02<1:41:19,  3.33s/it]2025-07-27 19:34:45,977 - INFO - Checkpoint saved: 13800 bills processed
# Congress 114 HR:  74%|████████████████████████████████████████████▊                | 4808/6536 [3:06:38<1:38:47,  3.43s/it]2025-07-27 19:40:22,583 - INFO - Checkpoint saved: 13900 bills processed
# Congress 114 HR:  75%|█████████████████████████████████████████████▊               | 4908/6536 [3:12:22<1:28:24,  3.26s/it]2025-07-27 19:46:06,031 - INFO - Checkpoint saved: 14000 bills processed
# Congress 114 HR:  77%|██████████████████████████████████████████████▋              | 5008/6536 [3:17:58<1:21:33,  3.20s/it]2025-07-27 19:51:41,843 - INFO - Checkpoint saved: 14100 bills processed
# Congress 114 HR:  78%|███████████████████████████████████████████████▋             | 5108/6536 [3:23:47<1:18:57,  3.32s/it]2025-07-27 19:57:31,693 - INFO - Checkpoint saved: 14200 bills processed
# Congress 114 HR:  78%|███████████████████████████████████████████████▋             | 5113/6536 [3:24:05<1:21:22,  3.43s/it]2025-07-27 19:57:49,281 - WARNING - Rate limited. Waiting 125 seconds...
# Congress 114 HR:  80%|████████████████████████████████████████████████▌            | 5208/6536 [3:31:58<1:16:08,  3.44s/it]2025-07-27 20:05:42,959 - INFO - Checkpoint saved: 14300 bills processed
# Congress 114 HR:  80%|████████████████████████████████████████████████▉            | 5247/6536 [3:34:12<1:11:13,  3.32s/it]2025-07-27 20:07:55,348 - WARNING - Rate limited. Waiting 483 seconds...
# Congress 114 HR:  81%|███████████████████████████████████████████████▉           | 5308/6536 [5:19:44<48:41:25, 142.74s/it]2025-07-27 21:53:28,744 - INFO - Checkpoint saved: 14400 bills processed
# Congress 114 HR:  83%|██████████████████████████████████████████████████▍          | 5408/6536 [5:25:36<1:05:53,  3.50s/it]2025-07-27 21:59:20,057 - INFO - Checkpoint saved: 14500 bills processed
# Congress 114 HR:  84%|█████████████████████████████████████████████████████          | 5508/6536 [5:32:08<59:03,  3.45s/it]2025-07-27 22:05:52,575 - INFO - Checkpoint saved: 14600 bills processed
# Congress 114 HR:  86%|██████████████████████████████████████████████████████         | 5608/6536 [5:38:04<52:32,  3.40s/it]2025-07-27 22:11:53,581 - INFO - Checkpoint saved: 14700 bills processed
# Congress 114 HR:  87%|███████████████████████████████████████████████████████        | 5708/6536 [5:44:06<46:55,  3.40s/it]2025-07-27 22:17:50,575 - INFO - Checkpoint saved: 14800 bills processed
# Congress 114 HR:  89%|███████████████████████████████████████████████████████▉       | 5808/6536 [5:50:19<42:24,  3.50s/it]2025-07-27 22:24:04,022 - INFO - Checkpoint saved: 14900 bills processed
# Congress 114 HR:  90%|████████████████████████████████████████████████████████▉      | 5908/6536 [5:56:08<36:43,  3.51s/it]2025-07-27 22:29:52,807 - INFO - Checkpoint saved: 15000 bills processed
# Congress 114 HR:  92%|█████████████████████████████████████████████████████████▉     | 6008/6536 [6:02:30<37:53,  4.31s/it]2025-07-27 22:36:15,084 - INFO - Checkpoint saved: 15100 bills processed
# Congress 114 HR:  92%|██████████████████████████████████████████████████████████▏    | 6036/6536 [6:04:09<31:12,  3.74s/it]2025-07-27 22:37:53,268 - WARNING - HTTP 500 for https://api.congress.gov/v3/bill/114/hr/835/actions?api_key=ENV['CONGRESS_API_KEY']&limit=250&offset=0
# Congress 114 HR:  93%|██████████████████████████████████████████████████████████▊    | 6108/6536 [6:08:30<26:18,  3.69s/it]2025-07-27 22:42:14,183 - INFO - Checkpoint saved: 15200 bills processed
# Congress 114 HR:  95%|███████████████████████████████████████████████████████████▊   | 6208/6536 [6:14:11<18:47,  3.44s/it]2025-07-27 22:47:55,325 - INFO - Checkpoint saved: 15300 bills processed
# Congress 114 HR:  97%|████████████████████████████████████████████████████████████▊  | 6308/6536 [6:20:03<12:44,  3.35s/it]2025-07-27 22:53:47,342 - INFO - Checkpoint saved: 15400 bills processed
# Congress 114 HR:  98%|█████████████████████████████████████████████████████████████▊ | 6408/6536 [6:25:37<07:33,  3.54s/it]2025-07-27 22:59:21,493 - INFO - Checkpoint saved: 15500 bills processed
# Congress 114 HR:  98%|█████████████████████████████████████████████████████████████▊ | 6417/6536 [6:26:08<06:37,  3.34s/it]2025-07-27 22:59:50,489 - WARNING - Rate limited. Waiting 3 seconds...
# Congress 114 HR: 100%|██████████████████████████████████████████████████████████████▋| 6507/6536 [6:31:42<01:34,  3.27s/it]2025-07-27 23:05:26,078 - WARNING - Rate limited. Waiting 327 seconds...
# Congress 114 HR: 100%|█████████████████████████████████████████████████████████████▋| 6508/6536 [6:37:18<48:02, 102.93s/it]2025-07-27 23:11:01,863 - INFO - Checkpoint saved: 15600 bills processed
# Congress 114 HR: 100%|███████████████████████████████████████████████████████████████| 6536/6536 [6:38:48<00:00,  3.66s/it]
# 2025-07-27 23:12:29,503 - INFO - Fetching all S bills from Congress 114
# 2025-07-27 23:14:12,355 - INFO - Found 3548 S bills in Congress 114
# Congress 114 S:   0%|▎                                                                 | 14/3548 [00:55<4:03:40,  4.14s/it]2025-07-27 23:15:10,232 - WARNING - HTTP 500 for https://api.congress.gov/v3/bill/114/s/2847/actions?api_key=ENV['CONGRESS_API_KEY']&limit=250&offset=0
# Congress 114 S:   2%|█▎                                                                | 72/3548 [04:27<3:09:37,  3.27s/it]2025-07-27 23:18:42,652 - INFO - Checkpoint saved: 15700 bills processed
# Congress 114 S:   5%|███▏                                                             | 172/3548 [09:48<2:55:51,  3.13s/it]2025-07-27 23:24:03,486 - INFO - Checkpoint saved: 15800 bills processed
# Congress 114 S:   8%|████▉                                                            | 272/3548 [15:08<2:53:03,  3.17s/it]2025-07-27 23:29:23,898 - INFO - Checkpoint saved: 15900 bills processed
# Congress 114 S:  10%|██████▊                                                          | 372/3548 [20:35<2:45:57,  3.14s/it]2025-07-27 23:34:50,868 - INFO - Checkpoint saved: 16000 bills processed
# Congress 114 S:  13%|████████▋                                                        | 472/3548 [26:01<3:34:57,  4.19s/it]2025-07-27 23:40:17,003 - INFO - Checkpoint saved: 16100 bills processed
# Congress 114 S:  16%|██████████▍                                                      | 572/3548 [31:19<2:37:41,  3.18s/it]2025-07-27 23:45:34,261 - INFO - Checkpoint saved: 16200 bills processed
# Congress 114 S:  19%|████████████▎                                                    | 672/3548 [36:42<2:34:42,  3.23s/it]2025-07-27 23:50:57,893 - INFO - Checkpoint saved: 16300 bills processed
# Congress 114 S:  22%|██████████████▏                                                  | 772/3548 [42:17<2:31:33,  3.28s/it]2025-07-27 23:56:33,079 - INFO - Checkpoint saved: 16400 bills processed
# Congress 114 S:  25%|███████████████▉                                                 | 872/3548 [48:05<2:27:27,  3.31s/it]2025-07-28 00:02:20,722 - INFO - Checkpoint saved: 16500 bills processed
# Congress 114 S:  27%|█████████████████▊                                               | 972/3548 [53:30<2:19:07,  3.24s/it]2025-07-28 00:07:45,860 - INFO - Checkpoint saved: 16600 bills processed
# Congress 114 S:  30%|███████████████████▎                                            | 1072/3548 [59:00<2:34:04,  3.73s/it]2025-07-28 00:13:16,726 - INFO - Checkpoint saved: 16700 bills processed
# Congress 114 S:  33%|████████████████████▍                                         | 1172/3548 [1:04:28<2:03:50,  3.13s/it]2025-07-28 00:18:43,896 - INFO - Checkpoint saved: 16800 bills processed
# Congress 114 S:  34%|████████████████████▉                                         | 1198/3548 [1:05:51<2:03:54,  3.16s/it]2025-07-28 00:20:05,747 - WARNING - Rate limited. Waiting 1208 seconds...
# Congress 114 S:  36%|██████████████████████▏                                       | 1272/3548 [1:29:58<2:00:43,  3.18s/it]2025-07-28 00:44:14,380 - INFO - Checkpoint saved: 16900 bills processed
# Congress 114 S:  39%|███████████████████████▉                                      | 1372/3548 [1:35:29<1:59:38,  3.30s/it]2025-07-28 00:49:44,424 - INFO - Checkpoint saved: 17000 bills processed
# Congress 114 S:  41%|█████████████████████████▋                                    | 1472/3548 [1:41:13<1:49:23,  3.16s/it]2025-07-28 00:55:28,105 - INFO - Checkpoint saved: 17100 bills processed
# Congress 114 S:  44%|███████████████████████████▍                                  | 1572/3548 [1:46:32<1:45:01,  3.19s/it]2025-07-28 01:00:47,850 - INFO - Checkpoint saved: 17200 bills processed
# Congress 114 S:  47%|█████████████████████████████▏                                | 1672/3548 [1:52:00<1:39:40,  3.19s/it]2025-07-28 01:06:15,634 - INFO - Checkpoint saved: 17300 bills processed
# Congress 114 S:  50%|██████████████████████████████▉                               | 1772/3548 [1:57:19<1:35:28,  3.23s/it]2025-07-28 01:11:34,060 - INFO - Checkpoint saved: 17400 bills processed
# Congress 114 S:  53%|████████████████████████████████▋                             | 1872/3548 [2:02:38<1:26:31,  3.10s/it]2025-07-28 01:16:53,624 - INFO - Checkpoint saved: 17500 bills processed
# Congress 114 S:  54%|█████████████████████████████████▏                            | 1900/3548 [2:04:06<1:26:44,  3.16s/it]2025-07-28 01:18:20,251 - WARNING - HTTP 502 for https://api.congress.gov/v3/bill/114/s/1954/cosponsors?api_key=ENV['CONGRESS_API_KEY']&limit=250&offset=0
# Congress 114 S:  56%|██████████████████████████████████▍                           | 1972/3548 [2:08:10<1:29:15,  3.40s/it]2025-07-28 01:22:25,699 - INFO - Checkpoint saved: 17600 bills processed
# Congress 114 S:  58%|████████████████████████████████████▏                         | 2072/3548 [2:13:35<1:21:58,  3.33s/it]2025-07-28 01:27:50,986 - INFO - Checkpoint saved: 17700 bills processed
# Congress 114 S:  61%|█████████████████████████████████████▉                        | 2172/3548 [2:19:03<1:14:39,  3.26s/it]2025-07-28 01:33:18,134 - INFO - Checkpoint saved: 17800 bills processed
# Congress 114 S:  64%|███████████████████████████████████████▋                      | 2272/3548 [2:24:25<1:07:53,  3.19s/it]2025-07-28 01:38:40,105 - INFO - Checkpoint saved: 17900 bills processed
# Congress 114 S:  66%|█████████████████████████████████████████                     | 2351/3548 [2:28:36<1:02:58,  3.16s/it]2025-07-28 01:42:49,960 - WARNING - Rate limited. Waiting 2572 seconds...
# Congress 114 S:  67%|█████████████████████████████████████████▍                    | 2372/3548 [3:12:41<1:20:07,  4.09s/it]2025-07-28 02:26:56,173 - INFO - Checkpoint saved: 18000 bills processed
# Congress 114 S:  70%|████████████████████████████████████████████▌                   | 2472/3548 [3:18:01<59:41,  3.33s/it]2025-07-28 02:32:17,056 - INFO - Checkpoint saved: 18100 bills processed
# Congress 114 S:  72%|██████████████████████████████████████████████▍                 | 2572/3548 [3:23:18<50:01,  3.07s/it]2025-07-28 02:37:33,391 - INFO - Checkpoint saved: 18200 bills processed
# Congress 114 S:  75%|████████████████████████████████████████████████▏               | 2672/3548 [3:28:42<47:30,  3.25s/it]2025-07-28 02:42:57,775 - INFO - Checkpoint saved: 18300 bills processed
# Congress 114 S:  78%|██████████████████████████████████████████████████              | 2772/3548 [3:34:00<40:49,  3.16s/it]2025-07-28 02:48:15,001 - INFO - Checkpoint saved: 18400 bills processed
# Congress 114 S:  81%|███████████████████████████████████████████████████▊            | 2872/3548 [3:39:16<34:46,  3.09s/it]2025-07-28 02:53:31,310 - INFO - Checkpoint saved: 18500 bills processed
# Congress 114 S:  84%|█████████████████████████████████████████████████████▍          | 2963/3548 [3:44:04<30:17,  3.11s/it]2025-07-28 02:58:18,659 - WARNING - HTTP 502 for https://api.congress.gov/v3/bill/114/s/746/cosponsors?api_key=ENV['CONGRESS_API_KEY']&limit=250&offset=0
# Congress 114 S:  84%|█████████████████████████████████████████████████████▌          | 2972/3548 [3:44:39<31:55,  3.33s/it]2025-07-28 02:58:54,028 - INFO - Checkpoint saved: 18600 bills processed
# Congress 114 S:  87%|███████████████████████████████████████████████████████▍        | 3072/3548 [3:50:02<26:57,  3.40s/it]2025-07-28 03:04:17,223 - INFO - Checkpoint saved: 18700 bills processed
# Congress 114 S:  89%|█████████████████████████████████████████████████████████▏      | 3172/3548 [3:55:22<19:59,  3.19s/it]2025-07-28 03:09:37,097 - INFO - Checkpoint saved: 18800 bills processed
# Congress 114 S:  92%|███████████████████████████████████████████████████████████     | 3272/3548 [4:00:50<20:45,  4.51s/it]2025-07-28 03:15:06,061 - INFO - Checkpoint saved: 18900 bills processed
# Congress 114 S:  95%|████████████████████████████████████████████████████████████▊   | 3372/3548 [4:06:24<09:06,  3.11s/it]2025-07-28 03:20:39,008 - INFO - Checkpoint saved: 19000 bills processed
# Congress 114 S:  98%|██████████████████████████████████████████████████████████████▋ | 3472/3548 [4:11:40<03:55,  3.10s/it]2025-07-28 03:25:55,714 - INFO - Checkpoint saved: 19100 bills processed
# Congress 114 S: 100%|████████████████████████████████████████████████████████████████| 3548/3548 [4:15:40<00:00,  4.32s/it]
# 2025-07-28 03:29:52,683 - INFO - Fetching all HJRES bills from Congress 114
# 2025-07-28 03:29:54,959 - INFO - Found 108 HJRES bills in Congress 114
# Congress 114 HJRES:  22%|██████████████▍                                                  | 24/108 [01:18<04:25,  3.16s/it]2025-07-28 03:31:15,816 - INFO - Checkpoint saved: 19200 bills processed
# Congress 114 HJRES: 100%|████████████████████████████████████████████████████████████████| 108/108 [06:09<00:00,  3.42s/it]
# 2025-07-28 03:36:04,767 - INFO - Fetching all SJRES bills from Congress 114
# 2025-07-28 03:36:06,012 - INFO - Found 41 SJRES bills in Congress 114
# Congress 114 SJRES:  39%|█████████████████████████▊                                        | 16/41 [00:53<01:27,  3.50s/it]2025-07-28 03:37:02,039 - INFO - Checkpoint saved: 19300 bills processed
# Congress 114 SJRES: 100%|██████████████████████████████████████████████████████████████████| 41/41 [02:17<00:00,  3.34s/it]
# 2025-07-28 03:38:23,059 - INFO - Fetching all HR bills from Congress 115
# 2025-07-28 03:41:35,064 - INFO - Found 7401 HR bills in Congress 115
# Congress 115 HR:   1%|▋                                                                | 75/7401 [04:29<7:17:59,  3.59s/it]2025-07-28 03:46:08,068 - INFO - Checkpoint saved: 19400 bills processed
# Congress 115 HR:   2%|█▌                                                              | 175/7401 [10:23<6:11:49,  3.09s/it]2025-07-28 03:52:01,097 - INFO - Checkpoint saved: 19500 bills processed
# Congress 115 HR:   3%|██▏                                                             | 251/7401 [14:49<6:14:28,  3.14s/it]2025-07-28 03:56:26,239 - WARNING - Rate limited. Waiting 3390 seconds...
# Congress 115 HR:   4%|██▎                                                           | 275/7401 [1:12:40<6:48:58,  3.44s/it]2025-07-28 04:54:18,607 - INFO - Checkpoint saved: 19600 bills processed
# Congress 115 HR:   5%|███▏                                                          | 375/7401 [1:18:25<6:51:43,  3.52s/it]2025-07-28 05:00:04,772 - INFO - Checkpoint saved: 19700 bills processed
# Congress 115 HR:   6%|███▉                                                          | 475/7401 [1:24:19<6:31:30,  3.39s/it]2025-07-28 05:05:56,800 - INFO - Checkpoint saved: 19800 bills processed
# Congress 115 HR:   7%|████▍                                                         | 529/7401 [1:27:28<6:47:51,  3.56s/it]2025-07-28 05:09:09,726 - WARNING - HTTP 500 for https://api.congress.gov/v3/bill/115/hr/2740/actions?api_key=ENV['CONGRESS_API_KEY']&limit=250&offset=0
# Congress 115 HR:   8%|████▊                                                         | 575/7401 [1:30:12<6:27:07,  3.40s/it]2025-07-28 05:11:50,171 - INFO - Checkpoint saved: 19900 bills processed
# Congress 115 HR:   9%|█████▋                                                        | 675/7401 [1:35:54<6:42:04,  3.59s/it]2025-07-28 05:17:31,948 - INFO - Checkpoint saved: 20000 bills processed
# Congress 115 HR:  10%|██████▍                                                       | 775/7401 [1:41:22<6:08:09,  3.33s/it]2025-07-28 05:23:00,566 - INFO - Checkpoint saved: 20100 bills processed
# Congress 115 HR:  12%|███████▎                                                      | 875/7401 [1:46:51<6:10:57,  3.41s/it]2025-07-28 05:28:29,733 - INFO - Checkpoint saved: 20200 bills processed
# Congress 115 HR:  13%|████████▏                                                     | 975/7401 [1:52:38<6:35:39,  3.69s/it]2025-07-28 05:34:19,526 - INFO - Checkpoint saved: 20300 bills processed
# Congress 115 HR:  15%|████████▊                                                    | 1075/7401 [1:58:22<5:29:17,  3.12s/it]2025-07-28 05:39:59,982 - INFO - Checkpoint saved: 20400 bills processed
# Congress 115 HR:  16%|█████████▋                                                   | 1175/7401 [2:03:54<5:35:14,  3.23s/it]2025-07-28 05:45:32,180 - INFO - Checkpoint saved: 20500 bills processed
# Congress 115 HR:  17%|██████████▌                                                  | 1275/7401 [2:09:35<7:25:26,  4.36s/it]2025-07-28 05:51:12,983 - INFO - Checkpoint saved: 20600 bills processed
# Congress 115 HR:  18%|███████████▎                                                 | 1366/7401 [2:14:42<5:33:20,  3.31s/it]2025-07-28 05:56:19,275 - WARNING - Rate limited. Waiting 3390 seconds...
# Congress 115 HR:  19%|██████████▉                                                | 1375/7401 [3:11:47<103:58:46, 62.12s/it]2025-07-28 06:53:25,703 - INFO - Checkpoint saved: 20700 bills processed
# Congress 115 HR:  20%|████████████▏                                                | 1475/7401 [3:17:32<5:38:38,  3.43s/it]2025-07-28 06:59:10,484 - INFO - Checkpoint saved: 20800 bills processed
# Congress 115 HR:  21%|████████████▉                                                | 1575/7401 [3:23:19<5:30:53,  3.41s/it]2025-07-28 07:04:56,771 - INFO - Checkpoint saved: 20900 bills processed
# Congress 115 HR:  23%|█████████████▊                                               | 1675/7401 [3:28:54<5:11:38,  3.27s/it]2025-07-28 07:10:31,904 - INFO - Checkpoint saved: 21000 bills processed
# Congress 115 HR:  24%|██████████████▋                                              | 1775/7401 [3:34:28<5:13:58,  3.35s/it]2025-07-28 07:16:06,091 - INFO - Checkpoint saved: 21100 bills processed
# Congress 115 HR:  25%|███████████████▍                                             | 1875/7401 [3:40:11<5:31:20,  3.60s/it]2025-07-28 07:21:50,126 - INFO - Checkpoint saved: 21200 bills processed
# Congress 115 HR:  27%|████████████████▎                                            | 1975/7401 [3:45:39<5:00:58,  3.33s/it]2025-07-28 07:27:17,759 - INFO - Checkpoint saved: 21300 bills processed
# Congress 115 HR:  28%|█████████████████                                            | 2075/7401 [3:51:23<5:20:02,  3.61s/it]2025-07-28 07:33:00,796 - INFO - Checkpoint saved: 21400 bills processed
# Congress 115 HR:  29%|█████████████████▉                                           | 2175/7401 [3:57:04<4:38:56,  3.20s/it]2025-07-28 07:38:42,639 - INFO - Checkpoint saved: 21500 bills processed
# Congress 115 HR:  31%|██████████████████▊                                          | 2275/7401 [4:02:45<4:45:56,  3.35s/it]2025-07-28 07:44:23,029 - INFO - Checkpoint saved: 21600 bills processed
# Congress 115 HR:  32%|███████████████████▌                                         | 2375/7401 [4:08:28<4:37:00,  3.31s/it]2025-07-28 07:50:06,503 - INFO - Checkpoint saved: 21700 bills processed
# Congress 115 HR:  33%|████████████████████▍                                        | 2475/7401 [4:14:04<4:39:26,  3.40s/it]2025-07-28 07:55:42,513 - INFO - Checkpoint saved: 21800 bills processed
# Congress 115 HR:  34%|████████████████████▍                                        | 2481/7401 [4:14:25<4:37:57,  3.39s/it]2025-07-28 07:56:00,494 - WARNING - Rate limited. Waiting 3373 seconds...
# Congress 115 HR:  35%|█████████████████████▏                                       | 2575/7401 [5:16:14<4:57:21,  3.70s/it]2025-07-28 08:57:52,270 - INFO - Checkpoint saved: 21900 bills processed
# Congress 115 HR:  36%|██████████████████████                                       | 2675/7401 [5:22:12<4:33:36,  3.47s/it]2025-07-28 09:03:50,566 - INFO - Checkpoint saved: 22000 bills processed
# Congress 115 HR:  37%|██████████████████████▊                                      | 2775/7401 [5:28:01<4:37:01,  3.59s/it]2025-07-28 09:09:38,735 - INFO - Checkpoint saved: 22100 bills processed
# Congress 115 HR:  39%|███████████████████████▋                                     | 2875/7401 [5:33:42<4:11:06,  3.33s/it]2025-07-28 09:15:19,997 - INFO - Checkpoint saved: 22200 bills processed
# Congress 115 HR:  40%|████████████████████████▌                                    | 2975/7401 [5:39:35<4:02:15,  3.28s/it]2025-07-28 09:21:13,007 - INFO - Checkpoint saved: 22300 bills processed
# Congress 115 HR:  42%|█████████████████████████▎                                   | 3075/7401 [5:45:16<4:06:44,  3.42s/it]2025-07-28 09:26:54,660 - INFO - Checkpoint saved: 22400 bills processed
# Congress 115 HR:  43%|██████████████████████████▏                                  | 3175/7401 [5:51:00<4:02:36,  3.44s/it]2025-07-28 09:32:38,318 - INFO - Checkpoint saved: 22500 bills processed
# Congress 115 HR:  44%|██████████████████████████▉                                  | 3275/7401 [5:56:40<3:59:21,  3.48s/it]2025-07-28 09:38:18,630 - INFO - Checkpoint saved: 22600 bills processed
# Congress 115 HR:  46%|███████████████████████████▊                                 | 3375/7401 [6:02:20<3:42:07,  3.31s/it]2025-07-28 09:43:58,411 - INFO - Checkpoint saved: 22700 bills processed
# Congress 115 HR:  47%|████████████████████████████▋                                | 3475/7401 [6:08:04<3:46:14,  3.46s/it]2025-07-28 09:49:42,118 - INFO - Checkpoint saved: 22800 bills processed
# Congress 115 HR:  48%|█████████████████████████████▍                               | 3575/7401 [6:13:55<3:50:44,  3.62s/it]2025-07-28 09:55:32,877 - INFO - Checkpoint saved: 22900 bills processed
# Congress 115 HR:  49%|█████████████████████████████▋                               | 3608/7401 [6:15:54<3:42:45,  3.52s/it]2025-07-28 09:57:30,339 - WARNING - Rate limited. Waiting 3460 seconds...
# Congress 115 HR:  50%|██████████████████████████████▎                              | 3675/7401 [7:17:26<3:27:58,  3.35s/it]2025-07-28 10:59:03,847 - INFO - Checkpoint saved: 23000 bills processed
# Congress 115 HR:  51%|███████████████████████████████                              | 3775/7401 [7:23:27<3:21:28,  3.33s/it]2025-07-28 11:05:05,537 - INFO - Checkpoint saved: 23100 bills processed
# Congress 115 HR:  52%|███████████████████████████████▉                             | 3875/7401 [7:29:15<3:23:34,  3.46s/it]2025-07-28 11:10:57,726 - INFO - Checkpoint saved: 23200 bills processed
# Congress 115 HR:  54%|████████████████████████████████▊                            | 3975/7401 [7:35:02<3:13:15,  3.38s/it]2025-07-28 11:16:40,516 - INFO - Checkpoint saved: 23300 bills processed
# Congress 115 HR:  55%|█████████████████████████████████▌                           | 4075/7401 [7:40:47<3:30:01,  3.79s/it]2025-07-28 11:22:25,315 - INFO - Checkpoint saved: 23400 bills processed
# Congress 115 HR:  56%|██████████████████████████████████▍                          | 4175/7401 [7:46:30<2:59:19,  3.34s/it]2025-07-28 11:28:08,594 - INFO - Checkpoint saved: 23500 bills processed
# Congress 115 HR:  58%|███████████████████████████████████▏                         | 4275/7401 [7:52:27<2:57:33,  3.41s/it]2025-07-28 11:34:05,699 - INFO - Checkpoint saved: 23600 bills processed
# Congress 115 HR:  59%|████████████████████████████████████                         | 4375/7401 [7:58:11<2:59:57,  3.57s/it]2025-07-28 11:39:49,019 - INFO - Checkpoint saved: 23700 bills processed
# Congress 115 HR:  60%|████████████████████████████████████▉                        | 4475/7401 [8:04:02<2:40:25,  3.29s/it]2025-07-28 11:45:40,080 - INFO - Checkpoint saved: 23800 bills processed
# Congress 115 HR:  62%|█████████████████████████████████████▋                       | 4575/7401 [8:09:37<2:32:40,  3.24s/it]2025-07-28 11:51:14,771 - INFO - Checkpoint saved: 23900 bills processed
# Congress 115 HR:  63%|██████████████████████████████████████▌                      | 4675/7401 [8:15:25<2:41:58,  3.57s/it]2025-07-28 11:57:03,026 - INFO - Checkpoint saved: 24000 bills processed
# Congress 115 HR:  63%|██████████████████████████████████████▌                      | 4686/7401 [8:16:05<2:46:53,  3.69s/it]2025-07-28 11:57:41,578 - WARNING - Rate limited. Waiting 3478 seconds...
# Congress 115 HR:  65%|███████████████████████████████████████▎                     | 4775/7401 [9:19:21<2:34:42,  3.53s/it]2025-07-28 13:01:00,400 - INFO - Checkpoint saved: 24100 bills processed
# Congress 115 HR:  66%|████████████████████████████████████████▏                    | 4875/7401 [9:25:18<2:22:42,  3.39s/it]2025-07-28 13:06:56,530 - INFO - Checkpoint saved: 24200 bills processed
# Congress 115 HR:  67%|█████████████████████████████████████████                    | 4975/7401 [9:31:02<2:18:43,  3.43s/it]2025-07-28 13:12:40,505 - INFO - Checkpoint saved: 24300 bills processed
# Congress 115 HR:  69%|█████████████████████████████████████████▊                   | 5075/7401 [9:36:49<2:10:22,  3.36s/it]2025-07-28 13:18:27,399 - INFO - Checkpoint saved: 24400 bills processed
# Congress 115 HR:  70%|██████████████████████████████████████████▋                  | 5175/7401 [9:42:43<2:07:42,  3.44s/it]2025-07-28 13:24:21,661 - INFO - Checkpoint saved: 24500 bills processed
# Congress 115 HR:  71%|███████████████████████████████████████████▍                 | 5275/7401 [9:48:38<2:10:45,  3.69s/it]2025-07-28 13:30:17,355 - INFO - Checkpoint saved: 24600 bills processed
# Congress 115 HR:  73%|████████████████████████████████████████████▎                | 5375/7401 [9:54:39<1:52:04,  3.32s/it]2025-07-28 13:36:17,362 - INFO - Checkpoint saved: 24700 bills processed
# Congress 115 HR:  74%|████████████████████████████████████████████▍               | 5475/7401 [10:00:35<2:03:02,  3.83s/it]2025-07-28 13:42:13,239 - INFO - Checkpoint saved: 24800 bills processed
# Congress 115 HR:  75%|█████████████████████████████████████████████▏              | 5575/7401 [10:06:18<1:41:16,  3.33s/it]2025-07-28 13:47:56,577 - INFO - Checkpoint saved: 24900 bills processed
# Congress 115 HR:  77%|██████████████████████████████████████████████              | 5675/7401 [10:12:09<1:43:41,  3.60s/it]2025-07-28 13:53:47,543 - INFO - Checkpoint saved: 25000 bills processed
# Congress 115 HR:  78%|██████████████████████████████████████████████▋             | 5756/7401 [10:16:50<1:30:02,  3.28s/it]2025-07-28 13:58:25,412 - WARNING - Rate limited. Waiting 3521 seconds...
# Congress 115 HR:  78%|██████████████████████████████████████████████▊             | 5775/7401 [11:16:40<2:18:56,  5.13s/it]2025-07-28 14:58:18,659 - INFO - Checkpoint saved: 25100 bills processed
# Congress 115 HR:  79%|███████████████████████████████████████████████▋            | 5875/7401 [11:22:47<1:31:18,  3.59s/it]2025-07-28 15:04:25,962 - INFO - Checkpoint saved: 25200 bills processed
# Congress 115 HR:  81%|████████████████████████████████████████████████▍           | 5975/7401 [11:28:27<1:20:24,  3.38s/it]2025-07-28 15:10:06,006 - INFO - Checkpoint saved: 25300 bills processed
# Congress 115 HR:  82%|█████████████████████████████████████████████████▎          | 6075/7401 [11:34:28<1:17:41,  3.52s/it]2025-07-28 15:16:06,302 - INFO - Checkpoint saved: 25400 bills processed
# Congress 115 HR:  83%|██████████████████████████████████████████████████          | 6175/7401 [11:40:28<1:09:13,  3.39s/it]2025-07-28 15:22:05,867 - INFO - Checkpoint saved: 25500 bills processed
# Congress 115 HR:  85%|██████████████████████████████████████████████████▊         | 6275/7401 [11:46:26<1:11:00,  3.78s/it]2025-07-28 15:28:04,153 - INFO - Checkpoint saved: 25600 bills processed
# Congress 115 HR:  86%|█████████████████████████████████████████████████████▍        | 6375/7401 [11:52:24<57:47,  3.38s/it]2025-07-28 15:34:02,857 - INFO - Checkpoint saved: 25700 bills processed
# Congress 115 HR:  87%|██████████████████████████████████████████████████████▏       | 6475/7401 [11:58:17<52:50,  3.42s/it]2025-07-28 15:39:55,695 - INFO - Checkpoint saved: 25800 bills processed
# Congress 115 HR:  89%|███████████████████████████████████████████████████████       | 6575/7401 [12:04:08<46:16,  3.36s/it]2025-07-28 15:45:49,547 - INFO - Checkpoint saved: 25900 bills processed
# Congress 115 HR:  90%|███████████████████████████████████████████████████████▉      | 6675/7401 [12:10:02<44:21,  3.67s/it]2025-07-28 15:51:41,252 - INFO - Checkpoint saved: 26000 bills processed
# Congress 115 HR:  92%|████████████████████████████████████████████████████████▊     | 6775/7401 [12:16:11<37:38,  3.61s/it]2025-07-28 15:57:49,337 - INFO - Checkpoint saved: 26100 bills processed
# Congress 115 HR:  92%|████████████████████████████████████████████████████████▉     | 6801/7401 [12:17:39<33:19,  3.33s/it]2025-07-28 15:59:17,026 - WARNING - Rate limited. Waiting 3585 seconds...
# Congress 115 HR:  93%|█████████████████████████████████████████████████████████▌    | 6875/7401 [13:22:05<36:12,  4.13s/it]2025-07-28 17:03:43,429 - INFO - Checkpoint saved: 26200 bills processed
# Congress 115 HR:  94%|██████████████████████████████████████████████████████████▎   | 6967/7401 [13:27:28<32:19,  4.47s/it]2025-07-28 17:09:04,498 - WARNING - HTTP 502 for https://api.congress.gov/v3/bill/115/hr/552/subjects?api_key=ENV['CONGRESS_API_KEY']
# Congress 115 HR:  94%|██████████████████████████████████████████████████████████▍   | 6975/7401 [13:28:00<26:01,  3.67s/it]2025-07-28 17:09:38,787 - INFO - Checkpoint saved: 26300 bills processed
# Congress 115 HR:  96%|███████████████████████████████████████████████████████████▎  | 7075/7401 [13:33:54<19:35,  3.61s/it]2025-07-28 17:15:32,582 - INFO - Checkpoint saved: 26400 bills processed
# Congress 115 HR:  97%|████████████████████████████████████████████████████████████  | 7175/7401 [13:39:35<12:44,  3.38s/it]2025-07-28 17:21:13,147 - INFO - Checkpoint saved: 26500 bills processed
# Congress 115 HR:  98%|████████████████████████████████████████████████████████████▉ | 7275/7401 [13:45:09<07:17,  3.47s/it]2025-07-28 17:26:47,704 - INFO - Checkpoint saved: 26600 bills processed
# Congress 115 HR: 100%|█████████████████████████████████████████████████████████████▊| 7375/7401 [13:50:54<01:31,  3.53s/it]2025-07-28 17:32:32,660 - INFO - Checkpoint saved: 26700 bills processed
# Congress 115 HR: 100%|██████████████████████████████████████████████████████████████| 7401/7401 [13:52:21<00:00,  6.75s/it]
# 2025-07-28 17:33:56,380 - INFO - Fetching all S bills from Congress 115
# 2025-07-28 17:35:33,395 - INFO - Found 3805 S bills in Congress 115
# Congress 115 S:   2%|█▎                                                                | 74/3805 [04:22<3:17:49,  3.18s/it]2025-07-28 17:39:58,084 - INFO - Checkpoint saved: 26800 bills processed
# Congress 115 S:   5%|██▉                                                              | 174/3805 [10:01<3:25:08,  3.39s/it]2025-07-28 17:45:37,165 - INFO - Checkpoint saved: 26900 bills processed
# Congress 115 S:   7%|████▋                                                            | 274/3805 [15:29<3:10:17,  3.23s/it]2025-07-28 17:51:05,548 - INFO - Checkpoint saved: 27000 bills processed
# Congress 115 S:  10%|██████▍                                                          | 374/3805 [20:53<3:10:44,  3.34s/it]2025-07-28 17:56:29,761 - INFO - Checkpoint saved: 27100 bills processed
# Congress 115 S:  11%|██████▉                                                          | 408/3805 [22:45<3:02:05,  3.22s/it]2025-07-28 17:58:21,729 - WARNING - Rate limited. Waiting 3601 seconds...
# Congress 115 S:  12%|███████▊                                                       | 474/3805 [1:26:40<3:15:47,  3.53s/it]2025-07-28 19:02:16,646 - INFO - Checkpoint saved: 27200 bills processed
# Congress 115 S:  15%|█████████▌                                                     | 574/3805 [1:32:13<3:00:45,  3.36s/it]2025-07-28 19:07:49,669 - INFO - Checkpoint saved: 27300 bills processed
# Congress 115 S:  18%|███████████▏                                                   | 674/3805 [1:37:41<2:46:43,  3.20s/it]2025-07-28 19:13:17,412 - INFO - Checkpoint saved: 27400 bills processed
# Congress 115 S:  20%|████████████▊                                                  | 774/3805 [1:43:17<2:41:03,  3.19s/it]2025-07-28 19:18:53,710 - INFO - Checkpoint saved: 27500 bills processed
# Congress 115 S:  23%|██████████████▍                                                | 874/3805 [1:48:48<2:45:10,  3.38s/it]2025-07-28 19:24:24,210 - INFO - Checkpoint saved: 27600 bills processed
# Congress 115 S:  26%|████████████████▏                                              | 974/3805 [1:54:17<2:37:10,  3.33s/it]2025-07-28 19:29:53,810 - INFO - Checkpoint saved: 27700 bills processed
# Congress 115 S:  28%|█████████████████▌                                            | 1074/3805 [1:59:50<2:30:31,  3.31s/it]2025-07-28 19:35:26,225 - INFO - Checkpoint saved: 27800 bills processed
# Congress 115 S:  31%|███████████████████▏                                          | 1174/3805 [2:05:24<2:25:07,  3.31s/it]2025-07-28 19:41:00,243 - INFO - Checkpoint saved: 27900 bills processed
# Congress 115 S:  33%|████████████████████▊                                         | 1274/3805 [2:10:57<2:17:50,  3.27s/it]2025-07-28 19:46:33,311 - INFO - Checkpoint saved: 28000 bills processed
# Congress 115 S:  36%|██████████████████████▍                                       | 1374/3805 [2:16:18<2:09:20,  3.19s/it]2025-07-28 19:51:54,381 - INFO - Checkpoint saved: 28100 bills processed
# Congress 115 S:  38%|███████████████████████▎                                      | 1432/3805 [2:19:26<2:07:16,  3.22s/it]2025-07-28 19:55:01,881 - WARNING - Rate limited. Waiting 3351 seconds...
# Congress 115 S:  39%|████████████████████████                                      | 1474/3805 [3:17:34<1:59:29,  3.08s/it]2025-07-28 20:53:10,530 - INFO - Checkpoint saved: 28200 bills processed
# Congress 115 S:  41%|█████████████████████████▋                                    | 1574/3805 [3:22:50<2:00:49,  3.25s/it]2025-07-28 20:58:25,866 - INFO - Checkpoint saved: 28300 bills processed
# Congress 115 S:  44%|███████████████████████████▎                                  | 1674/3805 [3:28:15<1:54:25,  3.22s/it]2025-07-28 21:03:51,461 - INFO - Checkpoint saved: 28400 bills processed
# Congress 115 S:  47%|████████████████████████████▉                                 | 1774/3805 [3:33:37<1:50:58,  3.28s/it]2025-07-28 21:09:13,793 - INFO - Checkpoint saved: 28500 bills processed
# Congress 115 S:  49%|██████████████████████████████▌                               | 1874/3805 [3:38:57<1:39:46,  3.10s/it]2025-07-28 21:14:33,199 - INFO - Checkpoint saved: 28600 bills processed
# Congress 115 S:  52%|████████████████████████████████▏                             | 1974/3805 [3:44:15<1:35:00,  3.11s/it]2025-07-28 21:19:51,719 - INFO - Checkpoint saved: 28700 bills processed
# Congress 115 S:  54%|█████████████████████████████████▌                            | 2056/3805 [3:48:32<1:32:25,  3.17s/it]2025-07-28 21:24:08,964 - WARNING - HTTP 500 for https://api.congress.gov/v3/bill/115/s/2012/committees?api_key=ENV['CONGRESS_API_KEY']
# Congress 115 S:  55%|█████████████████████████████████▊                            | 2074/3805 [3:49:36<1:32:47,  3.22s/it]2025-07-28 21:25:12,438 - INFO - Checkpoint saved: 28800 bills processed
# Congress 115 S:  57%|███████████████████████████████████▍                          | 2174/3805 [3:55:02<1:27:13,  3.21s/it]2025-07-28 21:30:38,646 - INFO - Checkpoint saved: 28900 bills processed
# Congress 115 S:  60%|█████████████████████████████████████                         | 2274/3805 [4:00:32<1:19:57,  3.13s/it]2025-07-28 21:36:08,998 - INFO - Checkpoint saved: 29000 bills processed
# Congress 115 S:  62%|██████████████████████████████████████▋                       | 2374/3805 [4:06:20<1:18:39,  3.30s/it]2025-07-28 21:41:56,970 - INFO - Checkpoint saved: 29100 bills processed
# Congress 115 S:  65%|████████████████████████████████████████▎                     | 2474/3805 [4:11:52<1:13:18,  3.30s/it]2025-07-28 21:47:28,715 - INFO - Checkpoint saved: 29200 bills processed
# Congress 115 S:  68%|█████████████████████████████████████████▉                    | 2574/3805 [4:17:34<1:19:05,  3.85s/it]2025-07-28 21:53:11,348 - INFO - Checkpoint saved: 29300 bills processed
# Congress 115 S:  68%|██████████████████████████████████████████                    | 2585/3805 [4:18:12<1:07:43,  3.33s/it]2025-07-28 21:53:47,777 - WARNING - Rate limited. Waiting 3241 seconds...
# Congress 115 S:  70%|███████████████████████████████████████████▌                  | 2674/3805 [5:17:29<1:07:40,  3.59s/it]2025-07-28 22:53:06,168 - INFO - Checkpoint saved: 29400 bills processed
# Congress 115 S:  73%|██████████████████████████████████████████████▋                 | 2774/3805 [5:23:14<55:14,  3.22s/it]2025-07-28 22:58:50,254 - INFO - Checkpoint saved: 29500 bills processed
# Congress 115 S:  76%|██████████████████████████████████████████████▊               | 2874/3805 [5:29:15<1:25:58,  5.54s/it]2025-07-28 23:04:52,524 - INFO - Checkpoint saved: 29600 bills processed
# Congress 115 S:  78%|██████████████████████████████████████████████████              | 2974/3805 [5:34:58<45:58,  3.32s/it]2025-07-28 23:10:35,031 - INFO - Checkpoint saved: 29700 bills processed
# Congress 115 S:  81%|███████████████████████████████████████████████████▋            | 3074/3805 [5:40:26<39:12,  3.22s/it]2025-07-28 23:16:02,422 - INFO - Checkpoint saved: 29800 bills processed
# Congress 115 S:  83%|█████████████████████████████████████████████████████▍          | 3174/3805 [5:45:54<34:41,  3.30s/it]2025-07-28 23:21:30,597 - INFO - Checkpoint saved: 29900 bills processed
# Congress 115 S:  86%|███████████████████████████████████████████████████████         | 3274/3805 [5:51:28<28:23,  3.21s/it]2025-07-28 23:27:04,972 - INFO - Checkpoint saved: 30000 bills processed
# Congress 115 S:  89%|████████████████████████████████████████████████████████▊       | 3374/3805 [5:56:54<24:00,  3.34s/it]2025-07-28 23:32:30,595 - INFO - Checkpoint saved: 30100 bills processed
# Congress 115 S:  91%|██████████████████████████████████████████████████████████▍     | 3474/3805 [6:02:33<17:39,  3.20s/it]2025-07-28 23:38:09,713 - INFO - Checkpoint saved: 30200 bills processed
# Congress 115 S:  94%|████████████████████████████████████████████████████████████    | 3574/3805 [6:07:58<12:16,  3.19s/it]2025-07-28 23:43:34,210 - INFO - Checkpoint saved: 30300 bills processed
# Congress 115 S:  97%|█████████████████████████████████████████████████████████████▊  | 3674/3805 [6:13:25<06:55,  3.17s/it]2025-07-28 23:49:01,479 - INFO - Checkpoint saved: 30400 bills processed
# Congress 115 S:  99%|███████████████████████████████████████████████████████████████▍| 3774/3805 [6:19:07<01:41,  3.27s/it]2025-07-28 23:54:43,465 - INFO - Checkpoint saved: 30500 bills processed
# Congress 115 S:  99%|███████████████████████████████████████████████████████████████▌| 3776/3805 [6:19:14<01:36,  3.33s/it]2025-07-28 23:54:48,461 - WARNING - Rate limited. Waiting 3293 seconds...
# Congress 115 S: 100%|████████████████████████████████████████████████████████████████| 3805/3805 [7:15:45<00:00,  6.87s/it]
# 2025-07-29 00:51:19,478 - INFO - Fetching all HJRES bills from Congress 115
# 2025-07-29 00:51:23,186 - INFO - Found 146 HJRES bills in Congress 115
# Congress 115 HJRES:  47%|██████████████████████████████▋                                  | 69/146 [04:19<04:40,  3.65s/it]2025-07-29 00:55:45,706 - INFO - Checkpoint saved: 30600 bills processed
# Congress 115 HJRES: 100%|████████████████████████████████████████████████████████████████| 146/146 [08:36<00:00,  3.54s/it]
# 2025-07-29 00:59:59,602 - INFO - Fetching all SJRES bills from Congress 115
# 2025-07-29 01:00:02,998 - INFO - Found 69 SJRES bills in Congress 115
# Congress 115 SJRES:  33%|██████████████████████                                            | 23/69 [01:29<03:08,  4.10s/it]2025-07-29 01:01:35,632 - INFO - Checkpoint saved: 30700 bills processed
# Congress 115 SJRES: 100%|██████████████████████████████████████████████████████████████████| 69/69 [04:22<00:00,  3.81s/it]
# 2025-07-29 01:04:26,012 - INFO - Fetching all HR bills from Congress 116
# 2025-07-29 01:10:00,974 - INFO - Found 9067 HR bills in Congress 116
# Congress 116 HR:   1%|▍                                                               | 54/9067 [03:35<10:23:05,  4.15s/it]2025-07-29 01:13:39,645 - INFO - Checkpoint saved: 30800 bills processed
# Congress 116 HR:   2%|█                                                               | 154/9067 [09:36<8:34:39,  3.46s/it]2025-07-29 01:19:39,983 - INFO - Checkpoint saved: 30900 bills processed
# Congress 116 HR:   3%|█▊                                                              | 254/9067 [15:07<7:51:39,  3.21s/it]2025-07-29 01:25:11,417 - INFO - Checkpoint saved: 31000 bills processed
# Congress 116 HR:   4%|██▍                                                             | 354/9067 [20:42<7:46:14,  3.21s/it]2025-07-29 01:30:46,011 - INFO - Checkpoint saved: 31100 bills processed
# Congress 116 HR:   5%|███▏                                                            | 454/9067 [26:44<8:04:00,  3.37s/it]2025-07-29 01:36:48,426 - INFO - Checkpoint saved: 31200 bills processed
# Congress 116 HR:   6%|███▉                                                            | 554/9067 [32:12<8:24:15,  3.55s/it]2025-07-29 01:42:16,393 - INFO - Checkpoint saved: 31300 bills processed
# Congress 116 HR:   7%|████▌                                                           | 654/9067 [37:38<7:26:51,  3.19s/it]2025-07-29 01:47:42,016 - INFO - Checkpoint saved: 31400 bills processed
# Congress 116 HR:   8%|█████▎                                                          | 754/9067 [43:11<7:25:01,  3.21s/it]2025-07-29 01:53:14,813 - INFO - Checkpoint saved: 31500 bills processed
# Congress 116 HR:   9%|██████                                                          | 854/9067 [48:36<7:14:25,  3.17s/it]2025-07-29 01:58:39,716 - INFO - Checkpoint saved: 31600 bills processed
# Congress 116 HR:  10%|██████▏                                                         | 879/9067 [49:57<7:18:54,  3.22s/it]2025-07-29 02:00:09,474 - WARNING - HTTP 520 for https://api.congress.gov/v3/bill/116/hr/8515/committees?api_key=ENV['CONGRESS_API_KEY']
# 2025-07-29 02:00:14,915 - WARNING - HTTP 503 for https://api.congress.gov/v3/bill/116/hr/8515/committees?api_key=ENV['CONGRESS_API_KEY']
# 2025-07-29 02:00:25,602 - WARNING - HTTP 503 for https://api.congress.gov/v3/bill/116/hr/8515/committees?api_key=ENV['CONGRESS_API_KEY']
# Congress 116 HR:  10%|██████                                                         | 880/9067 [50:25<24:24:56, 10.74s/it]2025-07-29 02:00:27,345 - WARNING - HTTP 503 for https://api.congress.gov/v3/bill/116/hr/8522/cosponsors?api_key=ENV['CONGRESS_API_KEY']&limit=250&offset=0
# Congress 116 HR:  11%|██████▋                                                         | 954/9067 [54:53<7:58:45,  3.54s/it]2025-07-29 02:04:56,987 - INFO - Checkpoint saved: 31700 bills processed
# Congress 116 HR:  12%|███████                                                      | 1054/9067 [1:00:39<7:31:09,  3.38s/it]2025-07-29 02:10:43,609 - INFO - Checkpoint saved: 31800 bills processed
# Congress 116 HR:  13%|███████▊                                                     | 1154/9067 [1:06:24<7:40:09,  3.49s/it]2025-07-29 02:16:28,221 - INFO - Checkpoint saved: 31900 bills processed
# ...
# Congress 118 HR:  97%|██████████████████████████████████████████████████████████▎ | 10267/10564 [18:07:59<16:57,  3.43s/it]2025-07-31 18:10:07,913 - INFO - Checkpoint saved: 70600 bills processed
# Congress 118 HR:  98%|██████████████████████████████████████████████████████████▉ | 10367/10564 [18:13:47<11:26,  3.48s/it]2025-07-31 18:15:56,056 - INFO - Checkpoint saved: 70700 bills processed
# Congress 118 HR:  99%|███████████████████████████████████████████████████████████▍| 10467/10564 [18:19:46<05:41,  3.52s/it]2025-07-31 18:21:55,428 - INFO - Checkpoint saved: 70800 bills processed
# Congress 118 HR: 100%|████████████████████████████████████████████████████████████| 10564/10564 [18:25:39<00:00,  6.28s/it]
# 2025-07-31 18:27:45,326 - INFO - Fetching all S bills from Congress 118
# 2025-07-31 18:29:54,371 - INFO - Found 5649 S bills in Congress 118
# Congress 118 S:   0%|                                                                   | 3/5649 [00:11<6:17:46,  4.01s/it]2025-07-31 18:30:10,071 - INFO - Checkpoint saved: 70900 bills processed
# Congress 118 S:   2%|█▏                                                               | 103/5649 [06:09<5:44:24,  3.73s/it]2025-07-31 18:36:07,233 - INFO - Checkpoint saved: 71000 bills processed
# Congress 118 S:   4%|██▎                                                              | 203/5649 [11:34<4:48:58,  3.18s/it]2025-07-31 18:41:31,783 - INFO - Checkpoint saved: 71100 bills processed
# Congress 118 S:   5%|███▍                                                             | 298/5649 [16:43<4:41:47,  3.16s/it]2025-07-31 18:46:39,641 - WARNING - HTTP 502 for https://api.congress.gov/v3/bill/118/s/5504/subjects?api_key=ENV['CONGRESS_API_KEY']
# Congress 118 S:   5%|███▍                                                             | 303/5649 [17:05<5:32:53,  3.74s/it]2025-07-31 18:47:03,162 - INFO - Checkpoint saved: 71200 bills processed
# Congress 118 S:   7%|████▋                                                            | 403/5649 [22:23<4:47:53,  3.29s/it]2025-07-31 18:52:20,497 - INFO - Checkpoint saved: 71300 bills processed
# Congress 118 S:   9%|█████▊                                                           | 503/5649 [27:48<4:31:58,  3.17s/it]2025-07-31 18:57:45,522 - INFO - Checkpoint saved: 71400 bills processed
# Congress 118 S:   9%|██████                                                           | 527/5649 [29:06<4:38:22,  3.26s/it]2025-07-31 18:59:02,187 - WARNING - Rate limited. Waiting 3556 seconds...
# Congress 118 S:  11%|██████▋                                                        | 603/5649 [1:32:41<4:36:05,  3.28s/it]2025-07-31 20:02:40,390 - INFO - Checkpoint saved: 71500 bills processed
# Congress 118 S:  12%|███████▊                                                       | 703/5649 [1:38:27<4:37:09,  3.36s/it]2025-07-31 20:08:25,789 - INFO - Checkpoint saved: 71600 bills processed
# Congress 118 S:  14%|████████▉                                                      | 803/5649 [1:43:51<4:51:14,  3.61s/it]2025-07-31 20:13:49,519 - INFO - Checkpoint saved: 71700 bills processed
# Congress 118 S:  16%|██████████                                                     | 903/5649 [1:49:19<4:17:20,  3.25s/it]2025-07-31 20:19:17,086 - INFO - Checkpoint saved: 71800 bills processed
# Congress 118 S:  18%|███████████                                                   | 1003/5649 [1:54:46<4:05:32,  3.17s/it]2025-07-31 20:24:43,906 - INFO - Checkpoint saved: 71900 bills processed
# Congress 118 S:  20%|████████████                                                  | 1103/5649 [2:00:09<4:01:36,  3.19s/it]2025-07-31 20:30:06,810 - INFO - Checkpoint saved: 72000 bills processed
# Congress 118 S:  21%|█████████████▏                                                | 1203/5649 [2:05:35<4:03:43,  3.29s/it]2025-07-31 20:35:33,579 - INFO - Checkpoint saved: 72100 bills processed
# Congress 118 S:  23%|██████████████▎                                               | 1303/5649 [2:11:05<3:53:50,  3.23s/it]2025-07-31 20:41:03,575 - INFO - Checkpoint saved: 72200 bills processed
# Congress 118 S:  25%|███████████████▍                                              | 1403/5649 [2:16:39<3:54:56,  3.32s/it]2025-07-31 20:46:37,346 - INFO - Checkpoint saved: 72300 bills processed
# Congress 118 S:  27%|████████████████▍                                             | 1503/5649 [2:22:06<3:40:09,  3.19s/it]2025-07-31 20:52:04,347 - INFO - Checkpoint saved: 72400 bills processed
# Congress 118 S:  27%|█████████████████                                             | 1553/5649 [2:24:48<3:42:21,  3.26s/it]2025-07-31 20:54:43,286 - WARNING - Rate limited. Waiting 3318 seconds...
# Congress 118 S:  28%|█████████████████▌                                            | 1603/5649 [3:22:52<3:39:40,  3.26s/it]2025-07-31 21:52:50,526 - INFO - Checkpoint saved: 72500 bills processed
# Congress 118 S:  30%|██████████████████▋                                           | 1703/5649 [3:28:16<3:33:34,  3.25s/it]2025-07-31 21:58:14,074 - INFO - Checkpoint saved: 72600 bills processed
# Congress 118 S:  32%|███████████████████▊                                          | 1803/5649 [3:33:51<3:28:53,  3.26s/it]2025-07-31 22:03:49,332 - INFO - Checkpoint saved: 72700 bills processed
# Congress 118 S:  34%|████████████████████▉                                         | 1903/5649 [3:39:17<3:24:54,  3.28s/it]2025-07-31 22:09:15,582 - INFO - Checkpoint saved: 72800 bills processed
# Congress 118 S:  35%|█████████████████████▉                                        | 2003/5649 [3:44:41<3:14:53,  3.21s/it]2025-07-31 22:14:39,702 - INFO - Checkpoint saved: 72900 bills processed
# Congress 118 S:  37%|███████████████████████                                       | 2103/5649 [3:50:06<3:13:50,  3.28s/it]2025-07-31 22:20:03,774 - INFO - Checkpoint saved: 73000 bills processed
# Congress 118 S:  39%|████████████████████████▏                                     | 2203/5649 [3:55:35<3:17:59,  3.45s/it]2025-07-31 22:25:33,603 - INFO - Checkpoint saved: 73100 bills processed
# Congress 118 S:  41%|█████████████████████████▎                                    | 2303/5649 [4:01:08<3:07:51,  3.37s/it]2025-07-31 22:31:06,417 - INFO - Checkpoint saved: 73200 bills processed
# Congress 118 S:  43%|██████████████████████████▎                                   | 2403/5649 [4:06:44<3:07:21,  3.46s/it]2025-07-31 22:36:42,078 - INFO - Checkpoint saved: 73300 bills processed
# Congress 118 S:  44%|███████████████████████████▍                                  | 2503/5649 [4:12:11<2:49:23,  3.23s/it]2025-07-31 22:42:08,985 - INFO - Checkpoint saved: 73400 bills processed
# Congress 118 S:  46%|████████████████████████████▌                                 | 2603/5649 [4:17:39<2:45:53,  3.27s/it]2025-07-31 22:47:36,991 - INFO - Checkpoint saved: 73500 bills processed
# Congress 118 S:  48%|█████████████████████████████▋                                | 2703/5649 [4:23:02<2:36:27,  3.19s/it]2025-07-31 22:53:00,801 - INFO - Checkpoint saved: 73600 bills processed
# Congress 118 S:  48%|█████████████████████████████▊                                | 2715/5649 [4:23:42<2:38:07,  3.23s/it]2025-07-31 22:53:38,534 - WARNING - Rate limited. Waiting 3231 seconds...
# Congress 118 S:  50%|██████████████████████████████▊                               | 2803/5649 [5:22:33<2:34:05,  3.25s/it]2025-07-31 23:52:30,767 - INFO - Checkpoint saved: 73700 bills processed
# Congress 118 S:  51%|███████████████████████████████▊                              | 2903/5649 [5:28:12<2:25:28,  3.18s/it]2025-07-31 23:58:10,167 - INFO - Checkpoint saved: 73800 bills processed
# Congress 118 S:  53%|████████████████████████████████▉                             | 3003/5649 [5:33:43<2:20:36,  3.19s/it]2025-08-01 00:03:41,431 - INFO - Checkpoint saved: 73900 bills processed
# Congress 118 S:  55%|██████████████████████████████████                            | 3103/5649 [5:39:06<2:19:38,  3.29s/it]2025-08-01 00:09:05,000 - INFO - Checkpoint saved: 74000 bills processed
# Congress 118 S:  57%|███████████████████████████████████▏                          | 3203/5649 [5:44:33<2:13:40,  3.28s/it]2025-08-01 00:14:31,616 - INFO - Checkpoint saved: 74100 bills processed
# Congress 118 S:  58%|████████████████████████████████████▎                         | 3303/5649 [5:50:01<2:03:34,  3.16s/it]2025-08-01 00:19:59,840 - INFO - Checkpoint saved: 74200 bills processed
# Congress 118 S:  60%|█████████████████████████████████████▎                        | 3403/5649 [5:55:28<2:00:20,  3.21s/it]2025-08-01 00:25:26,249 - INFO - Checkpoint saved: 74300 bills processed
# Congress 118 S:  62%|██████████████████████████████████████▍                       | 3503/5649 [6:01:03<2:05:56,  3.52s/it]2025-08-01 00:31:03,437 - WARNING - HTTP 530 for https://api.congress.gov/v3/bill/118/s/2458/committees?api_key=ENV['CONGRESS_API_KEY']
# 2025-08-01 00:31:09,845 - INFO - Checkpoint saved: 74400 bills processed
# Congress 118 S:  64%|███████████████████████████████████████▌                      | 3603/5649 [6:06:39<1:51:12,  3.26s/it]2025-08-01 00:36:36,939 - INFO - Checkpoint saved: 74500 bills processed
# Congress 118 S:  66%|████████████████████████████████████████▋                     | 3703/5649 [6:12:03<1:45:31,  3.25s/it]2025-08-01 00:42:01,227 - INFO - Checkpoint saved: 74600 bills processed
# Congress 118 S:  67%|█████████████████████████████████████████▋                    | 3803/5649 [6:17:25<1:41:41,  3.30s/it]2025-08-01 00:47:23,857 - INFO - Checkpoint saved: 74700 bills processed
# Congress 118 S:  69%|██████████████████████████████████████████▊                   | 3903/5649 [6:22:44<1:31:18,  3.14s/it]2025-08-01 00:52:42,265 - INFO - Checkpoint saved: 74800 bills processed
# Congress 118 S:  69%|██████████████████████████████████████████▉                   | 3912/5649 [6:23:15<1:35:55,  3.31s/it]2025-08-01 00:53:11,332 - WARNING - Rate limited. Waiting 3196 seconds...
# Congress 118 S:  71%|███████████████████████████████████████████▉                  | 4003/5649 [7:21:27<1:25:37,  3.12s/it]2025-08-01 01:51:25,152 - INFO - Checkpoint saved: 74900 bills processed
# Congress 118 S:  73%|█████████████████████████████████████████████                 | 4103/5649 [7:26:43<1:20:56,  3.14s/it]2025-08-01 01:56:41,615 - INFO - Checkpoint saved: 75000 bills processed
# Congress 118 S:  74%|██████████████████████████████████████████████▏               | 4203/5649 [7:32:06<1:15:56,  3.15s/it]2025-08-01 02:02:04,228 - INFO - Checkpoint saved: 75100 bills processed
# Congress 118 S:  76%|███████████████████████████████████████████████▏              | 4303/5649 [7:37:23<1:08:39,  3.06s/it]2025-08-01 02:07:20,515 - INFO - Checkpoint saved: 75200 bills processed
# Congress 118 S:  78%|████████████████████████████████████████████████▎             | 4403/5649 [7:42:41<1:04:41,  3.11s/it]2025-08-01 02:12:39,185 - INFO - Checkpoint saved: 75300 bills processed
# Congress 118 S:  80%|█████████████████████████████████████████████████▍            | 4503/5649 [7:47:54<1:00:02,  3.14s/it]2025-08-01 02:17:51,990 - INFO - Checkpoint saved: 75400 bills processed
# Congress 118 S:  81%|████████████████████████████████████████████████████▏           | 4603/5649 [7:53:02<53:48,  3.09s/it]2025-08-01 02:22:59,985 - INFO - Checkpoint saved: 75500 bills processed
# Congress 118 S:  83%|█████████████████████████████████████████████████████▎          | 4703/5649 [7:58:10<49:07,  3.12s/it]2025-08-01 02:28:08,092 - INFO - Checkpoint saved: 75600 bills processed
# Congress 118 S:  85%|██████████████████████████████████████████████████████▍         | 4803/5649 [8:03:36<47:01,  3.33s/it]2025-08-01 02:33:34,391 - INFO - Checkpoint saved: 75700 bills processed
# Congress 118 S:  87%|███████████████████████████████████████████████████████▌        | 4903/5649 [8:08:47<38:34,  3.10s/it]2025-08-01 02:38:45,330 - INFO - Checkpoint saved: 75800 bills processed
# Congress 118 S:  89%|████████████████████████████████████████████████████████▋       | 5003/5649 [8:13:54<32:40,  3.03s/it]2025-08-01 02:43:52,305 - INFO - Checkpoint saved: 75900 bills processed
# Congress 118 S:  90%|█████████████████████████████████████████████████████████▊      | 5103/5649 [8:19:07<27:53,  3.06s/it]2025-08-01 02:49:05,422 - INFO - Checkpoint saved: 76000 bills processed
# Congress 118 S:  91%|██████████████████████████████████████████████████████████      | 5125/5649 [8:20:16<27:28,  3.15s/it]2025-08-01 02:50:12,057 - WARNING - Rate limited. Waiting 3017 seconds...
# Congress 118 S:  92%|██████████████████████████████████████████████████████████▉     | 5203/5649 [9:14:48<23:45,  3.20s/it]2025-08-01 03:44:46,483 - INFO - Checkpoint saved: 76100 bills processed
# Congress 118 S:  94%|████████████████████████████████████████████████████████████    | 5303/5649 [9:20:14<18:19,  3.18s/it]2025-08-01 03:50:12,236 - INFO - Checkpoint saved: 76200 bills processed
# Congress 118 S:  96%|█████████████████████████████████████████████████████████████▏  | 5403/5649 [9:25:34<13:12,  3.22s/it]2025-08-01 03:55:31,854 - INFO - Checkpoint saved: 76300 bills processed
# Congress 118 S:  97%|██████████████████████████████████████████████████████████████▎ | 5503/5649 [9:31:02<07:53,  3.24s/it]2025-08-01 04:01:00,688 - INFO - Checkpoint saved: 76400 bills processed
# Congress 118 S:  99%|███████████████████████████████████████████████████████████████▍| 5603/5649 [9:36:28<02:22,  3.09s/it]2025-08-01 04:06:26,258 - INFO - Checkpoint saved: 76500 bills processed
# Congress 118 S: 100%|███████████████████████████████████████████████████████████████▊| 5637/5649 [9:38:17<00:37,  3.13s/it]2025-08-01 04:08:13,338 - WARNING - HTTP 502 for https://api.congress.gov/v3/bill/118/s/19/actions?api_key=ENV['CONGRESS_API_KEY']&limit=250&offset=0
# Congress 118 S: 100%|████████████████████████████████████████████████████████████████| 5649/5649 [9:39:00<00:00,  6.15s/it]
# 2025-08-01 04:08:54,802 - INFO - Fetching all HJRES bills from Congress 118
# 2025-08-01 04:08:59,627 - INFO - Found 230 HJRES bills in Congress 118
# Congress 118 HJRES:  23%|███████████████▎                                                 | 54/230 [03:03<09:46,  3.33s/it]2025-08-01 04:12:06,130 - INFO - Checkpoint saved: 76600 bills processed
# Congress 118 HJRES:  67%|██████████████████████████████████████████▊                     | 154/230 [08:41<04:18,  3.40s/it]2025-08-01 04:17:44,985 - INFO - Checkpoint saved: 76700 bills processed
# Congress 118 HJRES: 100%|████████████████████████████████████████████████████████████████| 230/230 [13:06<00:00,  3.42s/it]
# 2025-08-01 04:22:06,755 - INFO - Fetching all SJRES bills from Congress 118
# 2025-08-01 04:22:09,482 - INFO - Found 122 SJRES bills in Congress 118
# Congress 118 SJRES:  20%|████████████▊                                                    | 24/122 [01:15<05:05,  3.12s/it]2025-08-01 04:23:28,382 - INFO - Checkpoint saved: 76800 bills processed
# Congress 118 SJRES: 100%|████████████████████████████████████████████████████████████████| 122/122 [06:43<00:00,  3.30s/it]
# 2025-08-01 04:28:56,924 - INFO - Saved 76897 bills to bills_with_features_full.csv
# 2025-08-01 04:28:57,067 - INFO - Saved 2536 bills with known outcomes for training
# ============================================================
# EXTRACTION COMPLETE
# ============================================================
# Total bills extracted: 76897
# Bills with known outcomes: 2536
# Pass rate: 81.1%
#
# Bills by Congress:
# congress
# 113     9091
# 114    10233
# 115    11421
# 116    14345
# 117    15242
# 118    16565
# Name: count, dtype: int64
#
# Bills by type:
# bill_type
# HR       49170
# S        26465
# HJRES      831
# SJRES      431
# Name: count, dtype: int64
#
# Sponsor party distribution:
# sponsor_party
# D          41343
# R          35087
# I            443
# L             13
# Unknown       11
# Name: count, dtype: int64
#
# Extraction completed successfully!
# Full dataset: ../data/bills_with_features_full.csv
# Training dataset: ../data/bills_training_data_full.csv
